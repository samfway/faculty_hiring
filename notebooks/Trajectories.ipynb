# %%
from faculty_hiring.misc.plotting import *  # Definitions for LABEL_SIZE and such
from faculty_hiring.misc.gaussian_kde import gaussian_kde
from faculty_hiring.models.simulation_engine import SimulationEngine
from faculty_hiring.models.sigmoid_models import SigmoidModel

import re
import os
from collections import Counter
from faculty_hiring.parse import faculty_parser, institution_parser
from faculty_hiring.parse import load
from faculty_hiring.scripts import add_zscores as cur
from scipy.stats import ttest_ind, ks_2samp, chi2_contingency
from scipy.optimize import curve_fit, minimize
from scipy.misc import factorial, comb
from mpl_toolkits.axes_grid1 import make_axes_locatable

import scipy as sp
import numpy as np
import palettable

# %%
cmap = palettable.tableau.Tableau_10.mpl_colormap
colors = palettable.tableau.Tableau_10.mpl_colors
sig_level = 0.05

faculty_file = '/Users/samway//Documents/Work/ClausetLab/projects/faculty_hiring/data/faculty_cs_0930.txt'
inst_file = '/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/inst_cs.txt'
dblp_dir = '/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/profiles_DBLP_all/'
gs_dir = '/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/profiles_GS_all/'

figures_dir = '/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/notebooks/figures/trajectories/'

# %%
inst = institution_parser.parse_institution_records(open(inst_file))
candidate_pools, job_pools, job_ranks, year_range = load.load_assistant_prof_pools(open(faculty_file),
                                                                                   school_info=inst,
                                                                                   ranking='pi_rescaled',
                                                                                   year_start=1970,
                                                                                   year_stop=2012,
                                                                                   year_step=1)

model_weights = np.array([33.50515855,-115.91673249,-91.18207735,10.74285411,40.06731808,4.32774111,0.85881908])
model = SigmoidModel(prob_function='all', weights=model_weights)
simulator = SimulationEngine(candidate_pools, job_pools, job_ranks, inst, model)

# %%
num_rounds = len(hires)
num_iterations = 100
women_per_year = {school:np.zeros((num_iterations, num_rounds)) for school in inst}
actual_women_per_year = {school:np.zeros(num_rounds) for school in inst}

for i, pool in enumerate(candidate_pools):
    for person, rank in pool:
        if person.is_female and person.first_asst_job_location in actual_women_per_year:
            actual_women_per_year[person.first_asst_job_location][i] += 1

for t in xrange(num_iterations):
    if t % 10 == 0:
        print t
    hires = simulator.generate_network(one_list=False)  # one_list=False keeps things separated by year!
    for r, hiring_round in enumerate(hires):
        for person, place in hiring_round:
            if person.is_female and place in women_per_year:
                women_per_year[place][t][r] += 1
                
print 'Done!'
# Out:
# 0
# 10
# 20

# %% [markdown]
# ## Individual school

# %%
school = 'Stanford University'

color1 = ALMOST_BLACK
color2 = FEMALE_COLOR

fig, ax1 = plt.subplots(figsize=(8,4))
divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=1.2, pad=0.1, sharey=ax1)
axs = [ax1, ax2]
max_women = 0
final_counts = []

# Plot simulated trajectories
for t in xrange(num_iterations):
    trajectory = np.cumsum(women_per_year[school][t])
    ax1.plot(year_range[1:], trajectory, color=color2, linewidth=LINE_WIDTH, alpha=0.2)
    
    if trajectory[-1] > max_women:
        max_women = trajectory[-1]
    final_counts.append(trajectory[-1])
    
# Plot the actual trajectory
trajectory = np.cumsum(actual_women_per_year[school])
ax1.plot(year_range[1:], trajectory, color=color1, linewidth=LINE_WIDTH)
    
y_pad = 0.5
upper_y = np.max([max_women + 1, trajectory[-1] + 1])
ax1.set_xlim(year_range[0], year_range[-1])
ax1.set_ylim(-y_pad, upper_y-y_pad)
ax2_x = arange(0, upper_y)
ax2_y = np.array([sum(x == final_counts) for x in ax2_x], dtype=float)
ax2_y /= np.sum(ax2_y)
ax2.barh(ax2_x, ax2_y, color=color2, edgecolor='None', align='center', height=BAR_WIDTH)

ind = int(where(ax2_x == trajectory[-1])[0])
ax2.barh(ax2_x[ind], ax2_y[ind], edgecolor='None', align='center', color=color1, height=BAR_WIDTH)

ax1.set_ylabel('Cumulative number of female hires', fontsize=LABEL_SIZE)
ax1.set_xlabel('Hiring year', fontsize=LABEL_SIZE)
ax2.set_xticks([])
ax2.set_yticks(ax2_x)
#ax2.set_xlim((0, np.max(ax2_y)+.05))
ax2.set_ylim(-y_pad, upper_y-y_pad)
ax2.set_ylabel('Distribution under simulation', fontsize=LABEL_SIZE)
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")

for i in xrange(2):
    axs[i].tick_params(axis='both', which='major', labelsize=TICK_SIZE)
    axs[i].tick_params(axis='x', pad=XLABEL_PAD)

# %% [markdown]
# ## All the schools

# %%
color1 = ALMOST_BLACK
color2 = FEMALE_COLOR

for school in inst:
    tag = re.sub('[^a-zA-Z]+', '_', school)

    fig, ax1 = plt.subplots(figsize=(8,4))
    divider = make_axes_locatable(ax1)
    ax2 = divider.append_axes("right", size=1.2, pad=0.1, sharey=ax1)
    axs = [ax1, ax2]
    max_women = 0
    final_counts = []

    # Plot simulated trajectories
    for t in xrange(num_iterations):
        trajectory = np.cumsum(women_per_year[school][t])
        ax1.plot(year_range[1:], trajectory, color=color2, linewidth=LINE_WIDTH, alpha=0.2)

        if trajectory[-1] > max_women:
            max_women = trajectory[-1]
        final_counts.append(trajectory[-1])
        
    # Plot the actual trajectory
    trajectory = np.cumsum(actual_women_per_year[school])
    ax1.plot(year_range[1:], trajectory, color=color1, linewidth=LINE_WIDTH)

    y_pad = 0.5
    upper_y = np.max([max_women + 1, trajectory[-1] + 1])
    ax1.set_xlim(year_range[0], year_range[-1])
    ax1.set_ylim(-y_pad, upper_y-y_pad)
    ax2_x = arange(0, upper_y)
    ax2_y = np.array([sum(x == final_counts) for x in ax2_x], dtype=float)
    ax2_y /= np.sum(ax2_y)
    ax2.barh(ax2_x, ax2_y, color=color2, edgecolor='None', align='center', height=BAR_WIDTH)

    ind = int(where(ax2_x == trajectory[-1])[0])
    ax2.barh(ax2_x[ind], ax2_y[ind], edgecolor='None', align='center', color=color1, height=BAR_WIDTH)

    ax1.set_ylabel('Cumulative number of female hires', fontsize=LABEL_SIZE)
    ax1.set_xlabel('Hiring year', fontsize=LABEL_SIZE)
    ax2.set_xticks([])
    ax2.set_yticks(ax2_x)
    ax2.set_ylim(-y_pad, upper_y-y_pad)
    ax2.set_ylabel('Distribution under simulation', fontsize=LABEL_SIZE)
    ax2.yaxis.tick_right()
    ax2.yaxis.set_label_position("right")

    for i in xrange(2):
        axs[i].tick_params(axis='both', which='major', labelsize=TICK_SIZE)
        axs[i].tick_params(axis='x', pad=XLABEL_PAD)
        
    plt.savefig(os.path.join(figures_dir, '%s.pdf' % tag))
    fig.clf()
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-e457df1e5530> in <module>()
#      50         axs[i].tick_params(axis='x', pad=XLABEL_PAD)
#      51
# ---> 52     plt.savefig(os.path.join(figures_dir, '%s.pdf' % tag))
#      53     fig.clf()
#      54     plt.close()
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     575 def savefig(*args, **kwargs):
#     576     fig = gcf()
# --> 577     res = fig.savefig(*args, **kwargs)
#     578     draw()   # need this if 'transparent=True' to reset colors
#     579     return res
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, *args, **kwargs)
#    1474             self.set_frameon(frameon)
#    1475
# -> 1476         self.canvas.print_figure(*args, **kwargs)
#    1477
#    1478         if frameon:
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2209                 orientation=orientation,
#    2210                 bbox_inches_restore=_bbox_inches_restore,
# -> 2211                 **kwargs)
#    2212         finally:
#    2213             if bbox_inches and restore_bbox:
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/backends/backend_pdf.pyc in print_pdf(self, filename, **kwargs)
#    2483                 RendererPdf(file, image_dpi),
#    2484                 bbox_inches_restore=_bbox_inches_restore)
# -> 2485             self.figure.draw(renderer)
#    2486             renderer.finalize()
#    2487         finally:
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1117
#    1118         for tick in ticks_to_draw:
# -> 1119             tick.draw(renderer)
#    1120
#    1121         # scale up the axis label box to also find the neighbors, not
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer)
#     242                 self.gridline.draw(renderer)
#     243             if self.tick1On:
# --> 244                 self.tick1line.draw(renderer)
#     245             if self.tick2On:
#     246                 self.tick2line.draw(renderer)
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/lines.pyc in draw(self, renderer)
#     758                 renderer.draw_markers(gc, marker_path, marker_trans,
#     759                                       subsampled, affine.frozen(),
# --> 760                                       rgbaFace)
#     761
#     762                 alt_marker_path = marker.get_alt_path()
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/backends/backend_pdf.pyc in draw_markers(self, gc, marker_path, marker_trans, path, trans, rgbFace)
#    1672         if len_marker_path * uses < len_marker_path + uses + 5:
#    1673             RendererBase.draw_markers(self, gc, marker_path, marker_trans,
# -> 1674                                       path, trans, rgbFace)
#    1675             return
#    1676
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in draw_markers(self, gc, marker_path, marker_trans, path, trans, rgbFace)
#     257         once and reuse it multiple times.
#     258         """
# --> 259         for vertices, codes in path.iter_segments(trans, simplify=False):
#     260             if len(vertices):
#     261                 x, y = vertices[-2:]
#
# /Users/samway/Documents/Work/PythonEnvironments/science/lib/python2.7/site-packages/matplotlib/path.pyc in iter_segments(self, transform, remove_nans, clip, snap, stroke_width, simplify, curves, sketch)
#     413         i = 0
#     414         while i < len_vertices:
# --> 415             code = codes[i]
#     416             if code == STOP:
#     417                 return
#
# KeyboardInterrupt:
