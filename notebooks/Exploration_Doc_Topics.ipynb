# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Helvetica']
import matplotlib.pyplot as plt
import matplotlib as mpl
from faculty_hiring.misc.plotting import *  # Definitions for LABEL_SIZE and such
from brewer2mpl import sequential

from collections import Counter
import numpy as np

# %%
doc_topics_file = '/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles_mallet/doc_topics.txt'
topic_descriptions = \
    ['Computer Architecture',
     'Image/Signal Processing',
     'Data/Text Mining',
     'Software Engineering',
     'AI, Machine Learning',
     'Communication Networks',
     'Robotics, HCI, Social Systems',
     'Theory',
     'Computational Biology',
     'Programming Languages']

# %%
def parse_doc_topics(doc_topics_file):
    
    # Get the last line, number of documents
    with open(doc_topics_file, 'rb') as fh:
        first = next(fh)
        offset = -100
        while True:
            fh.seek(offset, 2)
            lines = fh.readlines()
            if len(lines)>1:
                last = lines[-1]
                break
            offset *= 2
    
    pieces = last.split()
    num_docs = int(pieces[0]) + 1
    num_topics = (len(last.split()) - 2) / 2
    num_pieces = len(pieces)
    doc_topics = np.zeros((num_docs, num_topics), dtype=float)
    filenames = []

    for line in open(doc_topics_file, 'rU'):
        if line.startswith('#'):
            continue  # Skip comments
        pieces = line.strip().split()
        doc = int(pieces[0])
        filenames.append(pieces[1])
        
        for i in xrange(2, num_pieces, 2):
            doc_topics[doc][int(pieces[i])] = float(pieces[i+1])
            
    return filenames, doc_topics

# %%
filenames, doc_topics = parse_doc_topics(doc_topics_file)
num_topics = doc_topics.shape[1]
num_docs = doc_topics.shape[0]

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/e7VI_HcAAAAJ.txt')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Aaron Clauset', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/5HLGWrIAAAAJ.txt')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Liz Bradley', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/8OYE6iEAAAAJ.txt')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('David Blei', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/eAFxlZIAAAAJ.txt')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Ehud Sharlin (Human-Robot Interaction)', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/37frPb8AAAAJ.txt')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Salil Vadhan (Theory of Computation; Cryptography)', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/XlDo0wgAAAAJ.txt')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Martin P. Robillard (Programming Languages)', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %% [markdown]
# ## How many people in each field/topic?

# %%
fig, ax = plt.subplots(figsize=(6, 4))
totals = np.sum(doc_topics > 0.2, axis=0)
ax.bar(xrange(num_topics), height=totals, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of authors', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Most probable topic

# %%
fig, ax = plt.subplots(figsize=(6, 4))

most_probable = np.argmax(doc_topics, axis=1)
top_topic_counts = Counter(most_probable)
top_topic_totals = zeros(num_topics)
for i in xrange(num_topics):
    top_topic_totals[i] = top_topic_counts[i]

ax.bar(xrange(num_topics), height=top_topic_totals, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of authors', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Probability of most used topic

# %%
fig, ax = plt.subplots(figsize=(6, 4))

most_probable = np.max(doc_topics, axis=1)
ax.hist(most_probable, 30, color='0.8')
ax.set_xlabel('Probability of most probable topic', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of faculty', fontsize=LABEL_SIZE)
ax.set_xlim(0,1)
plt.show()

# %%
fig, axs = plt.subplots(num_topics, 1, figsize=(4, 20))

all_max = np.max(doc_topics, axis=1)
bins = np.linspace(0, 1, 70)

for i in xrange(num_topics):
    keep = where(np.argmax(doc_topics, axis=1) == i)[0]
    most_probable = all_max[keep]
    axs[i].hist(most_probable, bins=bins, color='0.8')
    #ax.set_xlabel('Probability of most probable topic', fontsize=LABEL_SIZE)
    #ax.set_ylabel('Number of faculty', fontsize=LABEL_SIZE)
    axs[i].set_xlim(0,1)
    axs[i].set_title('Topic #%d' % i)
axs[-1].set_xlabel('Probability of topic')
plt.show()

# %% [markdown]
# ## Average profile

# %%
fig, ax = plt.subplots(figsize=(6, 4))

v_avg = np.zeros(num_topics, dtype=float)

for v in doc_topics:
    v_avg += np.sort(v)[::-1]
v_avg /= num_docs
    
ax.bar(xrange(num_topics), height=v_avg, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Sorted topic, 0 is most probable', fontsize=LABEL_SIZE)
ax.set_ylabel('Average probability', fontsize=LABEL_SIZE)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))

v_avg = np.zeros(num_topics, dtype=float)

for v in doc_topics:
    v_avg += np.cumsum(np.sort(v)[::-1])
v_avg /= num_docs
    
ax.bar(xrange(num_topics), height=v_avg, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Sorted topic, 0 is most probable', fontsize=LABEL_SIZE)
ax.set_ylabel('Average cumulative probability', fontsize=LABEL_SIZE)
ax.set_ylim((0.5, 1.0))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/e7VI_HcAAAAJ.txt')
v_avg = np.cumsum(np.sort(doc_topics[author_index,:])[::-1])

ax.bar(xrange(num_topics), height=v_avg, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.plot([-xlim_pad, doc_topics.shape[1]-xlim_pad], [0.9, 0.9], '--k')
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Sorted topic, 0 is most probable', fontsize=LABEL_SIZE)
ax.set_ylabel('Cumulative probability', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Poster Children

# %%
for i in xrange(10):
    print i, filenames[argmax(doc_topics[:,i])]
# Out:
# 0 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/AopgnHAAAAAJ.txt
# 1 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/SXXEZhYAAAAJ.txt
# 2 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/v8ZQDf8AAAAJ.txt
# 3 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/0Kw6HY0AAAAJ.txt
# 4 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/WBCKQMsAAAAJ.txt
# 5 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/Wang_0002:Bin.txt
# 6 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/aD5ev8QAAAAJ.txt
# 7 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/agcYx2YAAAAJ.txt
# 8 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/1YvZ8LAAAAAJ.txt
# 9 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/Reynolds:John_C=.txt

# %%
selected_topic = 8
for i in xrange(num_docs):
    if doc_topics[i,selected_topic] > 0.8:
        print filenames[i], doc_topics[i,selected_topic]
# Out:
# file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/-JSn-WgAAAAJ.txt 0.857307375251
# file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/1YvZ8LAAAAAJ.txt 0.917266873359
# file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/jlaUqdoAAAAJ.txt 0.873913086603
# file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/Ltxp3GkAAAAJ.txt 0.886455760924
# file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/rfLIRakAAAAJ.txt 0.819071125645
