# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Helvetica']
import matplotlib.pyplot as plt
import matplotlib as mpl
from faculty_hiring.misc.plotting import *  # Definitions for LABEL_SIZE and such
from brewer2mpl import sequential

from collections import Counter
import numpy as np

# %%
doc_topics_file = '/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles_mallet/doc_topics.txt'
topic_keys_file = '/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles_mallet/topic_keys.txt'

# %%
top_words = []
for line in open(topic_keys_file, 'rU'):
    line = line.strip()
    if line:
        pieces = line.split('\t')
        if len(pieces) == 3:
            top_words.append(pieces[2])

topic_descriptions = ['robots/hci', 'security', 'theory', 'vision', 'arch', 'distributed', 'data', 'sensor nets', 'software', 'ml']
            
for i, words in enumerate(top_words):
    print '%d & %s & %s \\\\ \hline' % (i, topic_descriptions[i], words)
# Out:
# 0 & robots/hci & environment system user design virtual interaction interface social interactive agent robot visualization computer information game digital learning behavior human \\ \hline
# 1 & security & security secure privacy attack key access encryption information mechanism application system network game detection protocol authentication trust control auction \\ \hline
# 2 & theory & algorithm graph problem complexity tree bound optimal approximation linear parallel computing efficient time computation random lower function application path \\ \hline
# 3 & vision & image recognition motion model video object detection analysis segmentation surface shape tracking estimation visual feature face data modeling robot \\ \hline
# 4 & arch & parallel memory performance design system architecture optimization application efficient algorithm processor power analysis dynamic cache energy scheduling multiprocessor data \\ \hline
# ...

# %%
def parse_doc_topics(doc_topics_file):
    
    # Get the last line, number of documents
    with open(doc_topics_file, 'rb') as fh:
        first = next(fh)
        offset = -100
        while True:
            fh.seek(offset, 2)
            lines = fh.readlines()
            if len(lines)>1:
                last = lines[-1]
                break
            offset *= 2
    
    pieces = last.split()
    num_docs = int(pieces[0]) + 1
    num_topics = (len(last.split()) - 2) / 2
    num_pieces = len(pieces)
    doc_topics = np.zeros((num_docs, num_topics), dtype=float)
    filenames = []

    for line in open(doc_topics_file, 'rU'):
        if line.startswith('#'):
            continue  # Skip comments
        pieces = line.strip().split()
        doc = int(pieces[0])
        filenames.append(pieces[1])
        
        for i in xrange(2, num_pieces, 2):
            doc_topics[doc][int(pieces[i])] = float(pieces[i+1])
            
    return filenames, doc_topics

# %%
filenames, doc_topics = parse_doc_topics(doc_topics_file)
num_topics = doc_topics.shape[1]
num_docs = doc_topics.shape[0]
file_string = 'file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/%s.txt'

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index(file_string % 'Clauset:Aaron')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color=DARK_COLOR, edgecolor='None')
tick_pad = 0.5
ax.set_title('Aaron Clauset', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability', fontsize=LABEL_SIZE)

hide_right_top_axis(ax)
ax.tick_params(axis='both', which='major', labelsize=LABEL_SIZE, pad=7)

plt.savefig('AaronClauset.pdf')
plt.show()  #Conte:Thomas_M= , Mueller:Frank

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index(file_string % 'Clauset:Aaron')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color=DARK_COLOR, edgecolor='None')
tick_pad = 0.5
ax.set_title('Aaron Clauset', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability', fontsize=LABEL_SIZE)

hide_right_top_axis(ax)
ax.tick_params(axis='both', which='major', labelsize=LABEL_SIZE, pad=7)

plt.savefig('AaronClauset.pdf')
plt.show()  #Conte:Thomas_M=

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index(file_string % 'Bradley:Elizabeth')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Liz Bradley', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index(file_string % 'Blei:David_M=')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('David Blei', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index(file_string % 'Sharlin:Ehud')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Ehud Sharlin (Human-Robot Interaction)', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index(file_string % 'Vadhan:Salil_P=')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Salil Vadhan (Theory of Computation; Cryptography)', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
author_index = filenames.index(file_string % 'Robillard:Martin_P=')
ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color='0.8')
tick_pad = 0.5
ax.set_title('Martin P. Robillard (Programming Languages)', fontsize=LABEL_SIZE)
ax.set_yticks(xrange(num_topics))
ax.set_ylim((-tick_pad, num_topics-tick_pad))
ax.set_yticklabels(topic_descriptions)
ax.set_xlabel('Probability')
plt.show()

# %%
fig, axs = plt.subplots(1, 5, figsize=(10, 3))

authors = [('Aaron Clauset', 'Clauset:Aaron', 'Colorado'),
           ('Frank Mueller', 'Mueller:Frank', 'NCSU'),
           ('Ehud Sharlin', 'Sharlin:Ehud', 'Calgary'),
           ('Michael Mitzenmacher', 'Mitzenmacher:Michael', 'Harvard'),
           ('David Blei', 'Blei:David_M=', 'Princeton')]

for i, ax in enumerate(axs):
    author_index = filenames.index(file_string % authors[i][1])
    ax.barh(xrange(doc_topics.shape[1]), doc_topics[author_index,:], align='center', color=DARK_COLOR, edgecolor='None')
    tick_pad = 0.5
    ax.set_title('%s\n(%s)' % (authors[i][0], authors[i][2]), fontsize=LABEL_SIZE)
    ax.set_ylim((-tick_pad, num_topics-tick_pad))
    ax.set_xlim(0,1)
    if i == 0:
        ax.set_yticks(xrange(num_topics))
        ax.set_yticklabels(topic_descriptions)
    else:
        ax.set_yticks([])
        ax.set_yticklabels([])

    hide_right_top_axis(ax)
    ax.tick_params(axis='both', which='major', labelsize=LABEL_SIZE, pad=7)
    ax.spines["bottom"].set_visible(False)
    ax.xaxis.set_ticks([])

plt.savefig('five_people.pdf')
plt.show()  #Conte:Thomas_M= , Mueller:Frank

# %% [markdown]
# ## How many people in each field/topic?

# %%
fig, ax = plt.subplots(figsize=(6, 4))
totals = np.sum(doc_topics > 0.2, axis=0)
ax.bar(xrange(num_topics), height=totals, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of authors', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Most probable topic

# %%
fig, ax = plt.subplots(figsize=(6, 4))

most_probable = np.argmax(doc_topics, axis=1)
top_topic_counts = Counter(most_probable)
top_topic_totals = zeros(num_topics)
for i in xrange(num_topics):
    top_topic_totals[i] = top_topic_counts[i]

ax.bar(xrange(num_topics), height=top_topic_totals, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of authors', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Probability of most used topic

# %%
fig, ax = plt.subplots(figsize=(6, 4))

most_probable = np.max(doc_topics, axis=1)
ax.hist(most_probable, 30, color='0.8')
ax.set_xlabel('Probability of most probable topic', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of faculty', fontsize=LABEL_SIZE)
ax.set_xlim(0,1)
plt.show()

# %%
fig, axs = plt.subplots(num_topics, 1, figsize=(4, 20))

all_max = np.max(doc_topics, axis=1)
bins = np.linspace(0, 1, 70)

for i in xrange(num_topics):
    keep = where(np.argmax(doc_topics, axis=1) == i)[0]
    most_probable = all_max[keep]
    axs[i].hist(most_probable, bins=bins, color='0.8')
    #ax.set_xlabel('Probability of most probable topic', fontsize=LABEL_SIZE)
    #ax.set_ylabel('Number of faculty', fontsize=LABEL_SIZE)
    axs[i].set_xlim(0,1)
    axs[i].set_title('Topic #%d' % i)
axs[-1].set_xlabel('Probability of topic')
plt.show()

# %% [markdown]
# ## Average profile

# %%
fig, ax = plt.subplots(figsize=(6, 4))

v_avg = np.zeros(num_topics, dtype=float)

for v in doc_topics:
    v_avg += np.sort(v)[::-1]
v_avg /= num_docs
    
ax.bar(xrange(num_topics), height=v_avg, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Sorted topic, 0 is most probable', fontsize=LABEL_SIZE)
ax.set_ylabel('Average probability', fontsize=LABEL_SIZE)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))

v_avg = np.zeros(num_topics, dtype=float)

for v in doc_topics:
    v_avg += np.cumsum(np.sort(v)[::-1])
v_avg /= num_docs
    
ax.bar(xrange(num_topics), height=v_avg, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Sorted topic, 0 is most probable', fontsize=LABEL_SIZE)
ax.set_ylabel('Average cumulative probability', fontsize=LABEL_SIZE)
ax.set_ylim((0.5, 1.0))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3))
author_index = filenames.index(file_string % 'Clauset:Aaron')
v_avg = np.cumsum(np.sort(doc_topics[author_index,:])[::-1])

ax.bar(xrange(num_topics), height=v_avg, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.plot([-xlim_pad, doc_topics.shape[1]-xlim_pad], [0.9, 0.9], '--k')
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Sorted topic, 0 is most probable', fontsize=LABEL_SIZE)
ax.set_ylabel('Cumulative probability', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Poster Children

# %%
for i in xrange(10):
    print i, filenames[argmax(doc_topics[:,i])]
# Out:
# 0 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/subfield/dblp_titles/Zhang_0003:Li.txt
# 1 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/subfield/dblp_titles/Cardei:Mihaela.txt
# 2 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/subfield/dblp_titles/Lysyanskaya:Anna.txt
# 3 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/subfield/dblp_titles/Bardzell:Jeffrey.txt
# 4 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/subfield/dblp_titles/Palmer:Luther_R=.txt
# 5 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/subfield/dblp_titles/Xie_0001:Yuan.txt
# 6 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/subfield/dblp_titles/Bunescu:Razvan_C=.txt
# 7 file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/subfield/dblp_titles/Reynolds:John_C=.txt
# ...

# %% [markdown]
# ## Weighted Distributions

# %%
max_papers = 1000
dists = np.zeros((num_topics, max_papers))

for f in fa
