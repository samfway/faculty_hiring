# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Helvetica']
import matplotlib.pyplot as plt
import matplotlib as mpl
from faculty_hiring.misc.plotting import *  # Definitions for LABEL_SIZE and such
from brewer2mpl import sequential

from collections import Counter
import numpy as np

# %%
doc_topics_file = '/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/doc_topics.txt'

# %%
def parse_doc_topics(doc_topics_file):
    
    # Get the last line, number of documents
    with open(doc_topics_file, 'rb') as fh:
        first = next(fh)
        offset = -100
        while True:
            fh.seek(offset, 2)
            lines = fh.readlines()
            if len(lines)>1:
                last = lines[-1]
                break
            offset *= 2
    
    pieces = last.split()
    num_docs = int(pieces[0]) + 1
    num_topics = (len(last.split()) - 2) / 2
    num_pieces = len(pieces)
    doc_topics = np.zeros((num_docs, num_topics), dtype=float)
    filenames = []

    for line in open(doc_topics_file, 'rU'):
        if line.startswith('#'):
            continue  # Skip comments
        pieces = line.strip().split()
        doc = int(pieces[0])
        filenames.append(pieces[1])
        
        for i in xrange(2, num_pieces, 2):
            doc_topics[doc][int(pieces[i])] = float(pieces[i+1])
            
    return filenames, doc_topics

# %%
filenames, doc_topics = parse_doc_topics(doc_topics_file)
num_topics = doc_topics.shape[1]
num_docs = doc_topics.shape[0]

# %%
fig, ax = plt.subplots(figsize=(6, 4))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/../titles/e7VI_HcAAAAJ.txt')
ax.bar(xrange(doc_topics.shape[1]), height=doc_topics[author_index,:], align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(doc_topics.shape[1]))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_title('Aaron Clauset', fontsize=LABEL_SIZE)
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Probability', fontsize=LABEL_SIZE)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/../titles/5HLGWrIAAAAJ.txt')
ax.bar(xrange(doc_topics.shape[1]), height=doc_topics[author_index,:], align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(doc_topics.shape[1]))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_title('Liz Bradley', fontsize=LABEL_SIZE)
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Probability', fontsize=LABEL_SIZE)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/../titles/8OYE6iEAAAAJ.txt')
ax.bar(xrange(num_topics), height=doc_topics[author_index,:], align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, num_topics-xlim_pad))
ax.set_title('David Blei', fontsize=LABEL_SIZE)
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Probability', fontsize=LABEL_SIZE)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/../titles/eAFxlZIAAAAJ.txt')
ax.bar(xrange(num_topics), height=doc_topics[author_index,:], align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, num_topics-xlim_pad))
ax.set_title('Ehud Sharlin (Human-Robot Interaction)', fontsize=LABEL_SIZE)
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Probability', fontsize=LABEL_SIZE)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/../titles/37frPb8AAAAJ.txt')
ax.bar(xrange(num_topics), height=doc_topics[author_index,:], align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, num_topics-xlim_pad))
ax.set_title('Salil Vadhan (Theory of Computation; Cryptography)', fontsize=LABEL_SIZE)
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Probability', fontsize=LABEL_SIZE)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/../titles/dYGSG4EAAAAJ.txt')
ax.bar(xrange(num_topics), height=doc_topics[author_index,:], align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, num_topics-xlim_pad))
ax.set_title('Amr A. Sabry (Programming Languages)', fontsize=LABEL_SIZE)
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Probability', fontsize=LABEL_SIZE)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
author_index = filenames.index('file:/Users/samway/Documents/Work/ClausetLab/projects/faculty_hiring/data/titles/../titles/XlDo0wgAAAAJ.txt')
ax.bar(xrange(num_topics), height=doc_topics[author_index,:], align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, num_topics-xlim_pad))
ax.set_title('Martin P. Robillard (Programming Languages)', fontsize=LABEL_SIZE)
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Probability', fontsize=LABEL_SIZE)
plt.show()  
# Software Engineering; Software Archive Mining; API Usability; Recommendation Systems; Natural Language Processing

# %% [markdown]
# ## How many people in each field/topic?

# %%
fig, ax = plt.subplots(figsize=(6, 4))
totals = np.sum(doc_topics > 0.2, axis=0)
ax.bar(xrange(num_topics), height=totals, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of authors', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Most probable topic

# %%
fig, ax = plt.subplots(figsize=(6, 4))

most_probable = np.argmax(doc_topics, axis=1)
top_topic_counts = Counter(most_probable)
top_topic_totals = zeros(num_topics)
for i in xrange(num_topics):
    top_topic_totals[i] = top_topic_counts[i]

ax.bar(xrange(num_topics), height=top_topic_totals, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Topic #', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of authors', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Probability of most used topic

# %%
fig, ax = plt.subplots(figsize=(6, 4))

most_probable = np.max(doc_topics, axis=1)
ax.hist(most_probable, 40, color='0.8')
ax.set_xlabel('Probability of most probable topic', fontsize=LABEL_SIZE)
ax.set_ylabel('Number of faculty', fontsize=LABEL_SIZE)
ax.set_xlim(0,1)
plt.show()

# %%
fig, axs = plt.subplots(num_topics, 1, figsize=(4, 20))

all_max = np.max(doc_topics, axis=1)
bins = np.linspace(0, 1, 70)

for i in xrange(num_topics):
    keep = where(np.argmax(doc_topics, axis=1) == i)[0]
    most_probable = all_max[keep]
    axs[i].hist(most_probable, bins=bins, color='0.8')
    #ax.set_xlabel('Probability of most probable topic', fontsize=LABEL_SIZE)
    #ax.set_ylabel('Number of faculty', fontsize=LABEL_SIZE)
    axs[i].set_xlim(0,1)
    axs[i].set_title('Topic #%d' % i)
axs[-1].set_xlabel('Probability of topic')
plt.clf()
plt.close()
#plt.show()  
print '^ Hid this figure...'
# Out:
# ^ Hid this figure...

# %% [markdown]
# ## Average profile

# %%
fig, ax = plt.subplots(figsize=(6, 4))

v_avg = np.zeros(num_topics, dtype=float)

for v in doc_topics:
    v_avg += np.sort(v)[::-1]
v_avg /= num_docs
    
ax.bar(xrange(num_topics), height=v_avg, align='center', color='0.8')
xlim_pad = 0.5
ax.set_xticks(xrange(num_topics))
ax.set_xlim((-xlim_pad, doc_topics.shape[1]-xlim_pad))
ax.set_xlabel('Sorted topic, 0 is most probable', fontsize=LABEL_SIZE)
ax.set_ylabel('Average probability', fontsize=LABEL_SIZE)
plt.show()

# %% [markdown]
# ## Co-usage of Topics
